# %% [markdown]
# <a href="https://colab.research.google.com/github/danielLeiteSilva/Exercicio_interface/blob/main/Classificacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv('Customer-Churn.csv')

# %%
dados.head()
# Out:
#    Maior65Anos Conjuge Dependentes  MesesDeContrato TelefoneFixo  \
# 0            0     Sim         Nao                1          Nao
# 1            0     Nao         Nao               34          Sim
# 2            0     Nao         Nao                2          Sim
# 3            0     Nao         Nao               45          Nao
# 4            0     Nao         Nao                2          Sim
#
#   VariasLinhasTelefonicas ServicoDeInternet SegurancaOnline BackupOnline  \
# 0    SemServicoTelefonico               DSL             Nao          Sim
# 1                     Nao               DSL             Sim          Nao
# 2                     Nao               DSL             Sim          Sim
# 3    SemServicoTelefonico               DSL             Sim          Nao
# 4                     Nao       FibraOptica             Nao          Nao
#
#   SeguroNoDispositivo SuporteTecnico TVaCabo StreamingDeFilmes TipoDeContrato  \
# ...

# %%
dicionario = {"Sim": 1, "Nao": 0}

novosDados = dados[["Conjuge", "Dependentes", "TelefoneFixo", "PagamentoOnline", "Churn"]].replace(dicionario)

# %%
novosDados
# Out:
#       Conjuge  Dependentes  TelefoneFixo  PagamentoOnline  Churn
# 0           1            0             0                1      0
# 1           0            0             1                0      0
# 2           0            0             1                1      1
# 3           0            0             0                0      0
# 4           0            0             1                1      1
# ...       ...          ...           ...              ...    ...
# 7038        1            1             1                1      0
# 7039        1            1             1                1      0
# 7040        1            1             0                1      0
# 7041        1            0             1                1      1
# 7042        0            0             1                1      0
#
# [7043 rows x 5 columns]
